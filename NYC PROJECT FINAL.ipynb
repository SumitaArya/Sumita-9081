# %% [markdown]
# # NYC PROJECT

# %%
import pandas as pd

# %%
nyc = pd.read_csv("311_Service_Requests_from_2010_to_Present original.csv")
# Out:
# C:\Users\Samiksha\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (48,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
nyc.shape
# Out:
# (300698, 53)

# %%
nyc.size
# Out:
# 15936994

# %%
print(type(nyc))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
nyc.head()
# Out:
#    Unique Key      Created Date    Closed Date Agency  \
# 0    32310363  12/31/2015 23:59  1/1/2016 0:55   NYPD
# 1    32309934  12/31/2015 23:59  1/1/2016 1:26   NYPD
# 2    32309159  12/31/2015 23:59  1/1/2016 4:51   NYPD
# 3    32305098  12/31/2015 23:57  1/1/2016 7:43   NYPD
# 4    32306529  12/31/2015 23:56  1/1/2016 3:24   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0
# 1                     No Access  Street/Sidewalk       11105.0
# 2                     No Access  Street/Sidewalk       10458.0
# ...

# %% [markdown]
# #So above dataset has 5 rows & 53 columns

# %%
# Variable dtypes
nyc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300698 entries, 0 to 300697
# Data columns (total 53 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unique Key                      300698 non-null  int64
#  1   Created Date                    300698 non-null  object
#  2   Closed Date                     298534 non-null  object
#  3   Agency                          300698 non-null  object
#  4   Agency Name                     300698 non-null  object
#  5   Complaint Type                  300698 non-null  object
#  6   Descriptor                      294784 non-null  object
#  7   Location Type                   300567 non-null  object
#  8   Incident Zip                    298083 non-null  float64
#  9   Incident Address                256288 non-null  object
#  10  Street Name                     256288 non-null  object
#  11  Cross Street 1                  251419 non-null  object
# ...

# %% [markdown]
# # 2nd point

# %%
# using date time
nyc['Created Date'] = pd.to_datetime(nyc['Created Date'])
nyc['Created Date']
# Out:
# 0        2015-12-31 23:59:00
# 1        2015-12-31 23:59:00
# 2        2015-12-31 23:59:00
# 3        2015-12-31 23:57:00
# 4        2015-12-31 23:56:00
#                  ...
# 300693   2015-03-29 00:33:00
# 300694   2015-03-29 00:33:00
# 300695   2015-03-29 00:33:00
# 300696   2015-03-29 00:33:00
# 300697   2015-03-29 00:33:00
# Name: Created Date, Length: 300698, dtype: datetime64[ns]

# %%
# now for closed date
nyc['Closed Date'] = pd.to_datetime(nyc['Closed Date'])
nyc['Closed Date']
# Out:
# 0        2016-01-01 00:55:00
# 1        2016-01-01 01:26:00
# 2        2016-01-01 04:51:00
# 3        2016-01-01 07:43:00
# 4        2016-01-01 03:24:00
#                  ...
# 300693                   NaT
# 300694   2015-03-29 02:33:00
# 300695   2015-03-29 03:40:00
# 300696   2015-03-29 04:38:00
# 300697   2015-03-29 04:41:00
# Name: Closed Date, Length: 300698, dtype: datetime64[ns]

# %%
nyc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300698 entries, 0 to 300697
# Data columns (total 53 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unique Key                      300698 non-null  int64
#  1   Created Date                    300698 non-null  datetime64[ns]
#  2   Closed Date                     298534 non-null  datetime64[ns]
#  3   Agency                          300698 non-null  object
#  4   Agency Name                     300698 non-null  object
#  5   Complaint Type                  300698 non-null  object
#  6   Descriptor                      294784 non-null  object
#  7   Location Type                   300567 non-null  object
#  8   Incident Zip                    298083 non-null  float64
#  9   Incident Address                256288 non-null  object
#  10  Street Name                     256288 non-null  object
# ...

# %%
nyc.head()
# Out:
#    Unique Key        Created Date         Closed Date Agency  \
# 0    32310363 2015-12-31 23:59:00 2016-01-01 00:55:00   NYPD
# 1    32309934 2015-12-31 23:59:00 2016-01-01 01:26:00   NYPD
# 2    32309159 2015-12-31 23:59:00 2016-01-01 04:51:00   NYPD
# 3    32305098 2015-12-31 23:57:00 2016-01-01 07:43:00   NYPD
# 4    32306529 2015-12-31 23:56:00 2016-01-01 03:24:00   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0
# 1                     No Access  Street/Sidewalk       11105.0
# ...

# %%
# ‘Request_Closing_Time’ as the time elapsed between request creation and request closing.

nyc['Request_Closing_Time'] = nyc['Closed Date'] - nyc['Created Date']

# %%
# yyyy:mm:dd hh:mm:ss

nyc['Request_Closing_Time']
# Out:
# 0        0 days 00:56:00
# 1        0 days 01:27:00
# 2        0 days 04:52:00
# 3        0 days 07:46:00
# 4        0 days 03:28:00
#                ...
# 300693               NaT
# 300694   0 days 02:00:00
# 300695   0 days 03:07:00
# 300696   0 days 04:05:00
# 300697   0 days 04:08:00
# Name: Request_Closing_Time, Length: 300698, dtype: timedelta64[ns]

# %%
# request closing time in days
nyc['response_days']= nyc['Request_Closing_Time']/np.timedelta64(1,'D')

# %%
nyc['response_days']
# Out:
# 0         0.038889
# 1         0.060417
# 2         0.202778
# 3         0.323611
# 4         0.144444
#             ...
# 300693         NaN
# 300694    0.083333
# 300695    0.129861
# 300696    0.170139
# 300697    0.172222
# Name: response_days, Length: 300698, dtype: float64

# %%
# request closing time in hours
nyc['response_hrs']= nyc['Request_Closing_Time']/np.timedelta64(1,'h')

# %%
nyc['response_hrs']
# Out:
# 0         0.933333
# 1         1.450000
# 2         4.866667
# 3         7.766667
# 4         3.466667
#             ...
# 300693         NaN
# 300694    2.000000
# 300695    3.116667
# 300696    4.083333
# 300697    4.133333
# Name: response_hrs, Length: 300698, dtype: float64

# %%
nyc.head()
# Out:
#    Unique Key        Created Date         Closed Date Agency  \
# 0    32310363 2015-12-31 23:59:00 2016-01-01 00:55:00   NYPD
# 1    32309934 2015-12-31 23:59:00 2016-01-01 01:26:00   NYPD
# 2    32309159 2015-12-31 23:59:00 2016-01-01 04:51:00   NYPD
# 3    32305098 2015-12-31 23:57:00 2016-01-01 07:43:00   NYPD
# 4    32306529 2015-12-31 23:56:00 2016-01-01 03:24:00   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0
# 1                     No Access  Street/Sidewalk       11105.0
# ...

# %%
# frequency of complaints types:

nyc['Complaint Type'].value_counts()
# Out:
# Blocked Driveway             77044
# Illegal Parking              75361
# Noise - Street/Sidewalk      48612
# Noise - Commercial           35577
# Derelict Vehicle             17718
# Noise - Vehicle              17083
# Animal Abuse                  7778
# Traffic                       4498
# Homeless Encampment           4416
# Noise - Park                  4042
# Vending                       3802
# Drinking                      1280
# Noise - House of Worship       931
# Posting Advertisement          650
# Urinating in Public            592
# Bike/Roller/Skate Chronic      427
# Panhandling                    307
# Disorderly Youth               286
# Illegal Fireworks              168
# Graffiti                       113
# Agency Issues                    6
# Squeegee                         4
# Ferry Complaint                  2
# Animal in a Park                 1
# Name: Complaint Type, dtype: int64

# %%
top_10_types = nyc['Complaint Type'].value_counts()[:10]

# %%
# bar plot for top 10 complaint type

top_10_types.plot(kind ='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 3rd Point

# %%
# Location count:
nyc['Location Type'].value_counts()
# Out:
# Street/Sidewalk               249299
# Store/Commercial               20381
# Club/Bar/Restaurant            17360
# Residential Building/House      6960
# Park/Playground                 4773
# House of Worship                 929
# Residential Building             227
# Highway                          215
# Parking Lot                      117
# House and Store                   93
# Vacant Lot                        77
# Commercial                        62
# Roadway Tunnel                    35
# Subway Station                    34
# Bridge                             2
# Terminal                           1
# Ferry                              1
# Park                               1
# Name: Location Type, dtype: int64

# %%
top_loc =nyc['Location Type'].value_counts()[:5]

# %%
top_loc
# Out:
# Street/Sidewalk               249299
# Store/Commercial               20381
# Club/Bar/Restaurant            17360
# Residential Building/House      6960
# Park/Playground                 4773
# Name: Location Type, dtype: int64

# %%
top_loc.plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='Location Type'>

# %%
# city
nyc['City'].value_counts()
# Out:
# BROOKLYN               98307
# NEW YORK               65994
# BRONX                  40702
# STATEN ISLAND          12343
# JAMAICA                 7296
# ASTORIA                 6330
# FLUSHING                5971
# RIDGEWOOD               5163
# CORONA                  4295
# WOODSIDE                3544
# SOUTH RICHMOND HILL     2774
# OZONE PARK              2755
# EAST ELMHURST           2734
# ELMHURST                2673
# WOODHAVEN               2464
# MASPETH                 2462
# LONG ISLAND CITY        2437
# SOUTH OZONE PARK        2173
# RICHMOND HILL           1904
# FRESH MEADOWS           1899
# QUEENS VILLAGE          1814
# MIDDLE VILLAGE          1765
# JACKSON HEIGHTS         1689
# FOREST HILLS            1688
# REGO PARK               1486
# BAYSIDE                 1221
# COLLEGE POINT           1220
# FAR ROCKAWAY            1179
# WHITESTONE              1098
# HOLLIS                  1012
# HOWARD BEACH             931
# ROSEDALE                 922
# ...

# %%
nyc_top_10city = nyc['City'].value_counts()[:10]

# %%
nyc_top_10city
# Out:
# BROOKLYN         98307
# NEW YORK         65994
# BRONX            40702
# STATEN ISLAND    12343
# JAMAICA           7296
# ASTORIA           6330
# FLUSHING          5971
# RIDGEWOOD         5163
# CORONA            4295
# WOODSIDE          3544
# Name: City, dtype: int64

# %%
nyc_top_10city.plot(kind ='bar')
# Out:
# <AxesSubplot:>

# %%
# avaerage response in days by city

nyc.groupby('City')['response_days'].mean()
# Out:
# City
# ARVERNE                0.094378
# ASTORIA                0.191614
# Astoria                0.174366
# BAYSIDE                0.111633
# BELLEROSE              0.439850
# BREEZY POINT           0.145671
# BRONX                  0.254006
# BROOKLYN               0.168666
# CAMBRIA HEIGHTS        0.421838
# CENTRAL PARK           0.137264
# COLLEGE POINT          0.136403
# CORONA                 0.134497
# EAST ELMHURST          0.149069
# ELMHURST               0.137942
# East Elmhurst          0.252083
# FAR ROCKAWAY           0.116248
# FLORAL PARK            0.488300
# FLUSHING               0.125753
# FOREST HILLS           0.134329
# FRESH MEADOWS          0.135997
# GLEN OAKS              0.367325
# HOLLIS                 0.239997
# HOWARD BEACH           0.256694
# Howard Beach           0.168056
# JACKSON HEIGHTS        0.136416
# JAMAICA                0.217083
# KEW GARDENS            0.210131
# LITTLE NECK            0.107387
# LONG ISLAND CITY       0.272462
# ...

# %% [markdown]
# # 4th Point

# %%
# Order the complaint types based on the average ‘Request_Closing_Time’ ,
# grouping them for different locations.

# %%
nyc.groupby('Complaint Type')['response_hrs'].mean()
# Out:
# Complaint Type
# Agency Issues                  5.258333
# Animal Abuse                   5.213219
# Animal in a Park             336.850000
# Bike/Roller/Skate Chronic      3.766234
# Blocked Driveway               4.740912
# Derelict Vehicle               7.364149
# Disorderly Youth               3.558333
# Drinking                       3.861791
# Ferry Complaint                     NaN
# Graffiti                       7.151327
# Homeless Encampment            4.365512
# Illegal Fireworks              2.761806
# Illegal Parking                4.501141
# Noise - Commercial             3.147195
# Noise - House of Worship       3.193416
# Noise - Park                   3.410724
# Noise - Street/Sidewalk        3.445181
# Noise - Vehicle                3.588981
# Panhandling                    4.372186
# Posting Advertisement          1.975694
# Squeegee                       4.045833
# Traffic                        3.448651
# Urinating in Public            3.626745
# ...

# %%
# grouping them for different locations.

# %%
df= nyc.groupby(['City' ,'Complaint Type'])['response_days'].mean()
# Out:
# City      Complaint Type
# ARVERNE   Animal Abuse               0.089748
#           Blocked Driveway           0.105298
#           Derelict Vehicle           0.123585
#           Disorderly Youth           0.149653
#           Drinking                   0.010417
#                                        ...
# Woodside  Blocked Driveway           0.266793
#           Derelict Vehicle           0.206944
#           Illegal Parking            0.217486
#           Noise - Commercial         0.099653
#           Noise - Street/Sidewalk    0.142222
# Name: response_days, Length: 764, dtype: float64

# %%
pd.pivot_table(nyc,index ='City',columns ='Complaint Type', values = 'response_hrs', aggfunc ='mean')
# Out:
# Complaint Type       Animal Abuse  Animal in a Park  \
# City
# ARVERNE                  2.153947               NaN
# ASTORIA                  5.000133               NaN
# Astoria                       NaN               NaN
# BAYSIDE                  3.274775               NaN
# BELLEROSE               12.723810               NaN
# BREEZY POINT             2.608333               NaN
# BRONX                    7.335501               NaN
# BROOKLYN                 4.832505               NaN
# CAMBRIA HEIGHTS         11.356061               NaN
# CENTRAL PARK                  NaN               NaN
# COLLEGE POINT            4.645238               NaN
# CORONA                   3.667760               NaN
# EAST ELMHURST            4.054520               NaN
# ELMHURST                 3.870175               NaN
# East Elmhurst                 NaN               NaN
# FAR ROCKAWAY             2.719850               NaN
# FLORAL PARK             26.583333               NaN
# ...

# %% [markdown]
# # 5th point

# %%
# Perform a statistical test

# %%
# we need to state the Null and Alternate and then provide a statistical test to accept or reject the Null Hypothesis along with the corresponding ‘p-value’.

# Whether the average response time across complaint types is similar or not (overall).

# %%
# y = response_days

# by Complaint types

# %%
# H0 = The average response time in days is same for differnet complaint types.

# Ha = The average response time in days is different for diffrent complaint types.

# %%
nyc['Complaint Type'].value_counts()[:5]
# Out:
# Blocked Driveway           77044
# Illegal Parking            75361
# Noise - Street/Sidewalk    48612
# Noise - Commercial         35577
# Derelict Vehicle           17718
# Name: Complaint Type, dtype: int64

# %%
df1= nyc[nyc['Complaint Type'] =='Blocked Driveway']

# %%
df2 = nyc[nyc['Complaint Type'] =='Illegal Parking ']

# %%
df3= nyc[nyc['Complaint Type'] =='Noise - Street/Sidewalk']

# %%
df4= nyc[nyc['Complaint Type'] =='Noise - Commercial']

# %%
df5= nyc[nyc['Complaint Type'] =='Derelict Vehicle']
df5
# Out:
#         Unique Key        Created Date         Closed Date Agency  \
# 14        32309424 2015-12-31 23:47:00 2016-01-01 10:17:00   NYPD
# 151       32306497 2015-12-31 21:07:00 2016-01-01 01:05:00   NYPD
# 255       32305124 2015-12-31 18:29:00 2015-12-31 19:51:00   NYPD
# 256       32308002 2015-12-31 18:29:00 2015-12-31 22:37:00   NYPD
# 295       32305798 2015-12-31 17:13:00 2015-12-31 17:58:00   NYPD
# ...            ...                 ...                 ...    ...
# 300476    30284819 2015-03-29 09:26:00 2015-03-29 19:31:00   NYPD
# 300488    30288640 2015-03-29 08:55:00 2015-03-29 12:44:00   NYPD
# 300500    30285441 2015-03-29 08:30:00 2015-03-29 11:15:00   NYPD
# 300523    30289188 2015-03-29 07:16:00 2015-03-29 09:06:00   NYPD
# 300593    30279760 2015-03-29 02:27:00 2015-03-29 07:12:00   NYPD
#
#                             Agency Name    Complaint Type          Descriptor  \
# 14      New York City Police Department  Derelict Vehicle  With License Plate
# ...

# %%
ar1 =df1['response_days'].dropna()
ar1
# Out:
# 1         0.060417
# 2         0.202778
# 7         0.075000
# 9         0.058333
# 10        0.325694
#             ...
# 300665    0.050694
# 300672    0.654167
# 300679    0.050694
# 300687    0.093750
# 300694    0.083333
# Name: response_days, Length: 76810, dtype: float64

# %%
ar2 =df2['response_days'].dropna()

# %%
ar3 =df3['response_days'].dropna()

# %%
ar4 =df4['response_days'].dropna()
ar5 =df5['response_days'].dropna()

# %%
# Run the anova model

import scipy.stats as stats

# %%
stats.f_oneway(ar1,ar2,ar3,ar4,ar5)
# Out:
# F_onewayResult(statistic=nan, pvalue=nan)

# %%
## H0 = The average response time in days is same for differnet complaint types.

# as the p value is nan or 0 , so we will reject.

# so the average respons time in days is not same in diffrent complaint types.

# %%
# Are the type of complaint or service requested and location related?

nyc['City'].value_counts()
# Out:
# BROOKLYN               98307
# NEW YORK               65994
# BRONX                  40702
# STATEN ISLAND          12343
# JAMAICA                 7296
# ASTORIA                 6330
# FLUSHING                5971
# RIDGEWOOD               5163
# CORONA                  4295
# WOODSIDE                3544
# SOUTH RICHMOND HILL     2774
# OZONE PARK              2755
# EAST ELMHURST           2734
# ELMHURST                2673
# WOODHAVEN               2464
# MASPETH                 2462
# LONG ISLAND CITY        2437
# SOUTH OZONE PARK        2173
# RICHMOND HILL           1904
# FRESH MEADOWS           1899
# QUEENS VILLAGE          1814
# MIDDLE VILLAGE          1765
# JACKSON HEIGHTS         1689
# FOREST HILLS            1688
# REGO PARK               1486
# BAYSIDE                 1221
# COLLEGE POINT           1220
# FAR ROCKAWAY            1179
# WHITESTONE              1098
# HOLLIS                  1012
# HOWARD BEACH             931
# ROSEDALE                 922
# ...

# %%
# Top 5 complaints

top_5_complaints = nyc['Complaint Type'].value_counts()[:5]

# %%
top_5_complaints
# Out:
# Blocked Driveway           77044
# Illegal Parking            75361
# Noise - Street/Sidewalk    48612
# Noise - Commercial         35577
# Derelict Vehicle           17718
# Name: Complaint Type, dtype: int64

# %%
top_5_complaints.index
# Out:
# Index(['Blocked Driveway', 'Illegal Parking', 'Noise - Street/Sidewalk',
#        'Noise - Commercial', 'Derelict Vehicle'],
#       dtype='object')

# %%
# Filter the DataFrame for the top_5_complaints:

nyc['Complaint Type'].isin(top_5_complaints.index)
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 300693    True
# 300694    True
# 300695    True
# 300696    True
# 300697    True
# Name: Complaint Type, Length: 300698, dtype: bool

# %%
City_top_5_Comp =nyc[nyc['Complaint Type'].isin(top_5_complaints.index)]

# %%
City_top_5_Comp
# Out:
#         Unique Key        Created Date         Closed Date Agency  \
# 0         32310363 2015-12-31 23:59:00 2016-01-01 00:55:00   NYPD
# 1         32309934 2015-12-31 23:59:00 2016-01-01 01:26:00   NYPD
# 2         32309159 2015-12-31 23:59:00 2016-01-01 04:51:00   NYPD
# 3         32305098 2015-12-31 23:57:00 2016-01-01 07:43:00   NYPD
# 4         32306529 2015-12-31 23:56:00 2016-01-01 03:24:00   NYPD
# ...            ...                 ...                 ...    ...
# 300693    30281872 2015-03-29 00:33:00                 NaT   NYPD
# 300694    30281230 2015-03-29 00:33:00 2015-03-29 02:33:00   NYPD
# 300695    30283424 2015-03-29 00:33:00 2015-03-29 03:40:00   NYPD
# 300696    30280004 2015-03-29 00:33:00 2015-03-29 04:38:00   NYPD
# 300697    30281825 2015-03-29 00:33:00 2015-03-29 04:41:00   NYPD
#
#                             Agency Name           Complaint Type  \
# 0       New York City Police Department  Noise - Street/Sidewalk
# ...

# %%
nyc['Complaint Type'] # it is a category
# Out:
# 0         Noise - Street/Sidewalk
# 1                Blocked Driveway
# 2                Blocked Driveway
# 3                 Illegal Parking
# 4                 Illegal Parking
#                    ...
# 300693         Noise - Commercial
# 300694           Blocked Driveway
# 300695         Noise - Commercial
# 300696         Noise - Commercial
# 300697         Noise - Commercial
# Name: Complaint Type, Length: 300698, dtype: object

# %%
nyc['City'] # it is also a category
# Out:
# 0              NEW YORK
# 1               ASTORIA
# 2                 BRONX
# 3                 BRONX
# 4              ELMHURST
#               ...
# 300693              NaN
# 300694    RICHMOND HILL
# 300695         BROOKLYN
# 300696            BRONX
# 300697         NEW YORK
# Name: City, Length: 300698, dtype: object

# %%
# Get a crosstab of the City & The Complaint Type:

City_Comp_Table =pd.crosstab(City_top_5_Comp['City'],City_top_5_Comp['Complaint Type'])

# %%
City_Comp_Table
# Out:
# Complaint Type       Blocked Driveway  Derelict Vehicle  Illegal Parking  \
# City
# ARVERNE                            35                27               58
# ASTORIA                          2618               351             1068
# Astoria                           116                12              213
# BAYSIDE                           377               198              514
# BELLEROSE                          95                89              106
# BREEZY POINT                        3                 3               15
# BRONX                           12755              1953             7859
# BROOKLYN                        28148              5181            27462
# CAMBRIA HEIGHTS                   147               115               76
# CENTRAL PARK                        0                 0                2
# COLLEGE POINT                     435               184              352
# CORONA                           2761                57              660
# ...

# %%
# Relationship bewteen City & Complaints

# chi Square = Categorical value

# h0: The City & the Complaint Type is independent to each other

# ha: The City & the Complaint Type is not independent to each other

# %%
chi2_stats,pvalue,df,mean_val= stats.chi2_contingency(City_Comp_Table)

# %%
chi2_stats
# Out:
# 72968.04166267907

# %%
chi2_stats = sum of all(actual-expected)/expected

# %%
pvalue
# Out:
# 0.0

# %%
as pvalue = 0 < alpha ,so we will reject the h0.

# The City & Complaint Type is not independent of each other.
